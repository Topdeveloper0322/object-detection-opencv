# %% [markdown]
# # 5. Arithmetic operations on images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 5.1 Adding 2 images
#
# We can mix two images with differents methods in OpenCV. With `add` function, the output doesn't look as expected, because intensity of pixels is added, literally, passing the '255' limit, with a saturation efect. With `addWeight` we can smooth this efect, the weight of each image can be adjusted.
#
#
# First of all, it is necessary that both images have same size to sum them. Most of the times, pictures will have different sizes so It is needed a way to resize one of them.
#
# One way to do this is using the `cv2`'s method `resize(image_to_resize,(col,row))`.

# %%
image_original1 = cv2.imread('imgs/paradrop.png')
image1 = image_original1.copy()

image_original2 = cv2.imread('imgs/index.jpeg')
image2 = image_original2.copy()


# RGB to BGR
image_BGR1 = cv2.cvtColor(image1, cv2.COLOR_RGB2BGR) 
image_BGR2 = cv2.cvtColor(image2, cv2.COLOR_RGB2BGR) 

fig, axes = plt.subplots(1, 2, figsize=(24,12))

# Color image
axes[0].imshow(image_BGR1)
axes[0].set_title('image 1')
axes[1].imshow(image_BGR2)
axes[1].set_title('image 2')

print(image_BGR1.shape)
# Out:
# (183, 275, 3)

# %%
row, col, channels = image_BGR1.shape
image2_resized = cv2.resize(image_BGR2, (col, row))

print("Flag image:    ", row, col, channels)
row, col, channels = image2_resized.shape
print("PepaPig Image: ",row, col, channels)
print("Both images have same dimensions.")

image_added = cv2.add(image_BGR1, image2_resized)

fig, axes = plt.subplots(1, 1, figsize=(18, 16))
axes.imshow(image_added)
axes.set_title('Add')
# Out:
# Flag image:     183 275 3
# PepaPig Image:  183 275 3
# Both images have same dimensions.
# Text(0.5, 1.0, 'Add')

# %% [markdown]
# Using this representation, both of the images have the same weight.
#
# There is a more elegant way to add to images giving weights to them. This can be achieve through the `cv2`'s method `addWeighted(image1,weight1,image2,weight,alpha)` where the weights should be in range [0,1]

# %%
image_mixed = cv2.addWeighted(image_BGR1, 0.1, image2_resized, 0.9, 0)

# Represent the images
fig, axes = plt.subplots(1, 2, figsize=(18, 16))
axes[0].imshow(image_added)
axes[0].set_title('Add')
axes[1].imshow(image_mixed)
axes[1].set_title('Mix')
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

# %% [markdown]
# In the code cell below, it is represented the sum of the images and the mix of them.
#
# This last one (mix) is so important. It is used to represent where is the ROI, highlighting it with a color for example.

# %% [markdown]
# ### 5.1.1 Adding 2 images with no regular shape

# %%
image_base = image_BGR1.copy()

image_top = cv2.resize(image_BGR2, (100, 100))

# Change one region for another with same size
image_base[83:183, 175:275] = image_top  



fig, axes = plt.subplots(1, 1, figsize=(12, 12))
axes.imshow(image_base)
axes.set_title('Region')
plt.xticks([]), plt.yticks([]);  
# to hide tick values on X and Y axis

# %%
hsv2 = cv2.cvtColor(image_top, cv2.COLOR_BGR2HSV)
hue2 = hsv2 [:,:,0] # Hue channel

maskHSV = cv2.inRange(hue2, 100, 150)
maskHSV =  maskHSV
color_filtred = cv2.bitwise_and(image_top, image_top, mask = maskHSV) 


# Represent with matplotlib the image. We can obtain his pixel values and coordinates.
fig, axes = plt.subplots(1, 2, figsize=(48, 48))
axes[0].imshow(maskHSV,cmap = 'gray')
axes[0].set_title('Hue mask')
axes[1].imshow(color_filtred)
axes[1].set_title('Segmented')
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])


    

print(image_base.shape)
print(image_top.shape)
# Out:
# (183, 275, 3)
# (100, 100, 3)

# %%
# Change one region for another with same size
# image_base[83:183, 175:275] = color_filtred
image_base2 = image_BGR1.copy()
row,col, dim = image_BGR1.shape
maskHSV = cv2.resize(maskHSV, (col, row))
color_filtred = cv2.resize(color_filtred, (col, row))
maskHSV_inverted = cv2.bitwise_not(maskHSV)

print(maskHSV.shape)
print(image_base.shape)

substracted = cv2.bitwise_and(image_BGR1,image_BGR1,mask = maskHSV_inverted)



# time to mixed it up

print(color_filtred.shape)
print(image_BGR1.shape)
mix = cv2.add(substracted, color_filtred)

fig, axes = plt.subplots(1, 5, figsize=(24, 18))
axes[0].imshow(image_base2, cmap='gray', vmin=0, vmax=255)
axes[0].set_title('roi')
axes[1].imshow(maskHSV, cmap='gray', vmin=0, vmax=255)
axes[1].set_title('Mask')
axes[2].imshow(substracted, cmap='gray', vmin=0, vmax=255)
axes[2].set_title('Substracted')
axes[3].imshow(maskHSV_inverted, cmap='gray', vmin=0, vmax=255)
axes[3].set_title('Without background')
axes[4].imshow(mix, cmap='gray', vmin=0, vmax=255)
axes[4].set_title('Final')
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
# Out:
# (183, 275)
# (183, 275, 3)
# (183, 275, 3)
# (183, 275, 3)
